# %% [markdown]
# <a href="https://colab.research.google.com/github/Lu120706/Proyecto-/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Flask

# %%
from flask import Flask, render_template_string, request, redirect, url_for
from pyngrok import ngrok

ngrok.set_auth_token("3BAZRkM8zxMXKV9qISrGVDjga5s_2Z9iWNeXsqSi4YFd3BYuy")

app = Flask(__name__)

ngrok.kill()

public_url = ngrok.connect(5000).public_url
print("Tu página:", public_url)
# Out:
# Tu página: https://marisol-unmilitant-airtightly.ngrok-free.dev

# %%
from os import error
login_html = """
<!DOCTYPE html>
<html>
<head>
  <title>Login</title>
</head>
<body style = "text-align:center; font-family:Arial;">
<h2>Inciar sesion</h2>
<form method= "POST">
  <input type="text" name="usuario" placeholder="Usuario" ><br><br>
  <input type="password" name= "password" placeholder="Contraseña" ><br><br>

  <select name="empresa">
    <option value= ""> Selecciona compañia </opcion>
    <option value = "GyJ Organizaciones"> GyJ organizaciones </option>
    <option value= "GyJ Ferreterias"> GyJ Ferreterias </option>
    <option value = "Colmena"> Colmena </option>
    <option value = "Almasa"> Almasa </option>
  </select><br><br>

<button type="submit">Ingresar</button>
</form>

<p style ="Color blanco"> {{error}}</p>

</body>
</html>
"""

dashboard_html = """
<!DOCTYPE html>
<html>
<head>
  <title>Panel</title>
</head>
<body style = "text-align:center; font-family:Arial;">
<h1> Bienvenido {{usuario}}</h1>
<h2> {{empresa}}</h2>
<button onclick = "alert('Mercado')"> Mercadeo </button>
<button onclick = "alert('Talento humano')"> Talento humano </button>
<button onclick = "alert('Gerencia')"> Gerencia </button>

</body>
</html>
"""

# %%
@app.route ("/", methods = ["GET", "POST"])
def login():
  error = ""
  if request.method =="POST":
    username = request.form ["usuario"]
    password = request.form ["password"]
    empresa = request.form ["empresa"]

    if username == "admin" and password == "adim123":
      return redirect(url_for("dashboard", empresa = empresa, usuario = username))
    else:
      error = "Usuario o contraseña incorrectos"

  return render_template_string(login_html, error=error)

@app.route("/dashboard")
def dashboard():
  usuario = request.args.get("usuario")
  empresa = request.args.get("empresa")
  return render_template_string(dashboard_html, usuario=usuario, empresa=empresa)

# %%
app.run(host="0.0.0.0", port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
